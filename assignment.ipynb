# %%
# !pwd
# Out:
# /home/cse-lab/Desktop/B192311

# %%
# !ls
# Out:
#  b192311.ipynb					  'Untitled Folder'
#  iris.csv					   Untitled.ipynb
#  MELBOURNE_HOUSE_PRICES_LESS.csv		   untitled.txt
# 'Python_assignment.docx - Python_assignment.pdf'

# %%
df.head(1)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")

# %%
variety_counts=df["variety"].value_counts()

variety_counts=dict(variety_counts)

print(variety_counts)
# Out:
# {'Setosa': 50, 'Versicolor': 50, 'Virginica': 50}

# %%
a=variety_counts.keys()
b=variety_counts.values()

# %%
fig = plt.figure(figsize=(9,9))

plt.pie(x=b,labels=a, explode=[0.1,0.1,0.1],shadow=True,autopct='%33.2f%%')
plt.axis("equal")
plt.legend()

plt.show()

# %%
import numpy as np

# %%
width=df["sepal.width"]
width=list(width)
length=df["sepal.length"]
length=list(length)

# %%
fig = plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.scatter(x=width,y=length)
x=np.random.randn(50)
y1=np.random.randn(50)
y2=np.random.randn(50)


plt.xlabel("sepal width")
plt.ylabel("sepal length")
plt.scatter(x,y1,color='r')
plt.scatter(x,y2,color='g')
plt.grid(color='black',linestyle='*')
plt.title("The Iris Data set")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-689af5d38ee4> in <module>
#      11 plt.scatter(x,y1,color='r')
#      12 plt.scatter(x,y2,color='g')
# ---> 13 plt.grid(color='black',linestyle='*')
#      14 plt.title("The Iris Data set")
#      15 plt.legend()
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in grid(b, which, axis, **kwargs)
#    2599 @docstring.copy(Axes.grid)
#    2600 def grid(b=None, which='major', axis='both', **kwargs):
# -> 2601     return gca().grid(b=b, which=which, axis=axis, **kwargs)
#    2602
#    2603
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2783         cbook._check_in_list(['x', 'y', 'both'], axis=axis)
#    2784         if axis in ['x', 'both']:
# -> 2785             self.xaxis.grid(b, which=which, **kwargs)
#    2786         if axis in ['y', 'both']:
#    2787             self.yaxis.grid(b, which=which, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1474             else:
#    1475                 self._gridOnMajor = b
# -> 1476             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
#    1477                                  **gridkw)
#    1478         self.stale = True
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     887             if which == 'major' or which == 'both':
#     888                 for tick in self.majorTicks:
# --> 889                     tick._apply_params(**kwtrans)
#     890             if which == 'minor' or which == 'both':
#     891                 for tick in self.minorTicks:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     381         grid_kw = {k[5:]: v for k, v in kw.items()
#     382                    if k in _gridline_param_names}
# --> 383         self.gridline.set(**grid_kw)
#     384         for k, v in grid_kw.items():
#     385             setattr(self, '_grid_' + k, v)
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1069             sorted(kwargs.items(), reverse=True,
#    1070                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1071         return self.update(props)
#    1072
#    1073     def findobj(self, match=None, include_self=True):
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#     969                     raise AttributeError('{!r} object has no property {!r}'
#     970                                          .format(type(self).__name__, k))
# --> 971                 return func(v)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
#
# /usr/lib/python3/dist-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1184                 ls = 'None'
#    1185
# -> 1186             cbook._check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1187             if ls not in self._lineStyles:
#    1188                 ls = ls_mapper_r[ls]
#
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(values, **kwargs)
#    2166     for k, v in kwargs.items():
#    2167         if v not in values:
# -> 2168             raise ValueError(
#    2169                 "{!r} is not a valid value for {}; supported values are {}"
#    2170                 .format(v, k, ', '.join(map(repr, values))))
#
# ValueError: '*' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     178     if _is_transparent(fig.get_facecolor()):
#     179         # the background is transparent
# --> 180         ticksLight = _is_light([label.get_color()
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# /usr/lib/python3/dist-packages/matplotlib/ticker.py in __call__(self)
#    2079     def __call__(self):
#    2080         vmin, vmax = self.axis.get_view_interval()
# -> 2081         return self.tick_values(vmin, vmax)
#    2082
#    2083     def tick_values(self, vmin, vmax):
#
# /usr/lib/python3/dist-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2087         vmin, vmax = mtransforms.nonsingular(
#    2088             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2089         locs = self._raw_ticks(vmin, vmax)
#    2090
#    2091         prune = self._prune
#
# /usr/lib/python3/dist-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2026         if self._nbins == 'auto':
#    2027             if self.axis is not None:
# -> 2028                 nbins = np.clip(self.axis.get_tick_space(),
#    2029                                 max(1, self._min_n_ticks - 1), 9)
#    2030             else:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in get_tick_space(self)
#    2181         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2182         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2183         tick = self._get_tick(True)
#    2184         # There is a heuristic here that the aspect ratio of tick text
#    2185         # is no more than 3:1
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
# --> 160         self.gridline = self._get_gridline()
#     161         self.label1 = self._get_text1()
#     162         self.label2 = self._get_text2()
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in _get_gridline(self)
#     485         'Get the default line2D instance'
#     486         # x in data coords, y in axes coords
# --> 487         l = mlines.Line2D(xdata=(0.0, 0.0), ydata=(0, 1.0),
#     488                           color=self._grid_color,
#     489                           linestyle=self._grid_linestyle,
#
# /usr/lib/python3/dist-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     375
#     376         self.set_linewidth(linewidth)
# --> 377         self.set_linestyle(linestyle)
#     378         self.set_drawstyle(drawstyle)
#     379
#
# /usr/lib/python3/dist-packages/matplotlib/lines.py in set_linestyle(self, ls)
#    1184                 ls = 'None'
#    1185
# -> 1186             cbook._check_in_list([*self._lineStyles, *ls_mapper_r], ls=ls)
#    1187             if ls not in self._lineStyles:
#    1188                 ls = ls_mapper_r[ls]
#
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(values, **kwargs)
#    2166     for k, v in kwargs.items():
#    2167         if v not in values:
# -> 2168             raise ValueError(
#    2169                 "{!r} is not a valid value for {}; supported values are {}"
#    2170                 .format(v, k, ', '.join(map(repr, values))))
#
# ValueError: '*' is not a valid value for ls; supported values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
